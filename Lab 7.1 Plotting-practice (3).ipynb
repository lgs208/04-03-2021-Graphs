# %% [markdown]
# # Lab 7.1 Plotting-practice

# %% [markdown]
# https://plotly.com/python/

# %% [markdown]
# https://realpython.com/ggplot-python/

# %% [markdown]
# # 0. Let's load and install some libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # 1. Let's load some data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### For each of the following tasks create a graph

# %% [markdown]
# ### **Task 1**. Is there any significant relationship between life expectancy and GDP in the UK ?

# %%
x = sns.regplot(x = 'gdpPercap', y = 'lifeExp', data = df[df['country']=='United Kingdom'])

# %% [markdown]
# ### **Task 2**. Plot the number of observations for each continent

# %%
a = sns.distplot(df[df['continent']=='Asia']['continent'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-939c60ef41b8> in <module>
# ----> 1 a = sns.distplot(df[df['continent']=='Asia']['continent'])
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     175
#     176     # Make a a 1-d float array
# --> 177     a = np.asarray(a, np.float)
#     178     if a.ndim > 1:
#     179         a = a.squeeze()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/series.py in __array__(self, dtype)
# ...

# %%
a = sns.countplot(df['continent'])

# %% [markdown]
# ### **Task 3**. Plot the evolution of life expectancy across different contintent

# %%
ax = sns.lineplot(x='year',y='lifeExp',hue='continent', data =df)

# %% [markdown]
# ### **Task 4**. Plot the distribution of lifeExp for different years and different continents using facetgrid

# %%
facet = sns.FacetGrid(df, col='year', hue='continent')
facet = facet.map(plt.hist, 'lifeExp')
facet = facet.add_legend()

# %% [markdown]
# ### **Task 6**. Boxplot for continent population for year 1980-1990

# %%
ax = sns.boxplot(x='continent', y='pop', data=df[(df['year']>=1980) & (df['year']<=1990)])
ax.set_title('Boxplot of continent population')
ax.set_xlabel('continent')
ax.set_ylabel('pop')
# Out:
# Text(0, 0.5, 'pop')
